# %%
name="brown_okutoi"
age=35
city="nairobi"
print(f"i_an_{name}")
# Out:
# i_an_brown_okutoi

# %%
students ={"name" : "brown",
           "age" : "35",
           "course" : "Gen_ai"}
print(students["course"])

# %%
name = "students"
print(f"hello_a.i_{name}")
# Out:
# hello_a.i_students

# %%
name="brown_okutoi"
age=35
city="nairobi"
print(f"i_an_{name}")
print(f"i_am_{age}")
print(f"i_live_in {city}")
# Out:
# i_an_brown_okutoi
# i_am_35
# i_live_in nairobi

# %%
#programing language
numbers = ["python","javascript","c++","sql","htpml",]
print(numbers[2])
# Out:
# c++
